# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
from collections import Counter
# reads in data, sourced from: https://www.covid19data.com.au/data-notes
df = pd.read_csv("cases_daily_aus.csv", )
#adds day column to data table assuming first day, 25 Jan is a Saturday
df.loc[:,"day"] = pd.Series(dict(
    zip([x for x in range(0,169)],
        ['saturday','sunday','monday','tuesday','wednesday','thursday','friday']*100)))
#build table of statistics with convoluted calls to pd.groupby(), sorry!
dayofweek_df = pd.DataFrame(pd.Series(Counter(df.day)))
dayofweek_df.columns = ["# of days"]
dayofweek_df.loc[:, "total cases"] = pd.Series(df.groupby("day").sum().to_dict()['new.cases'])
dayofweek_df.loc[:,"mean cases"] = pd.Series(df.groupby("day").mean().to_dict()['new.cases'])
#output
dayofweek_df.round(1)
# Out:
#            # of days  total cases  mean cases
# saturday          25         1603        64.1
# sunday            24         1177        49.0
# monday            24         1188        49.5
# tuesday           24         1382        57.6
# wednesday         24         1367        57.0
# thursday          24         1382        57.6
# friday            24         1504        62.7

# %%
#naive way is to sum all new.cases for each day
sum_cases_weekday = {}
for day in days:
    sum_cases_weekday[day] = df.loc[df.day == day]["new.cases"].sum()
sum_cases_weekday = pd.Series(sum_cases_weekday)
plt.bar(x = list(sum_cases_weekday.keys()), height = list(sum_cases_weekday.values))
plt.show()

# %%
pd.Series(df.groupby("day").sum().to_dict()['new.cases'])
# Out:
# friday       1504
# monday       1188
# saturday     1603
# sunday       1177
# thursday     1382
# tuesday      1382
# wednesday    1367
# dtype: int64

# %%
dayofweek_df = pd.DataFrame(pd.Series(Counter(df.day)))
dayofweek_df.columns = ["# of days"]
dayofweek_df.loc[:, "total cases"] = pd.Series(df.groupby("day").sum().to_dict()['new.cases'])
dayofweek_df.loc[:,"mean cases"] = pd.Series(df.groupby("day").mean().to_dict()['new.cases'])
#dayofweek_df.loc[:,"std dev"] = pd.Series(df.groupby("day").std().to_dict()['new.cases'])
dayofweek_df.round(1)
# Out:
#            # of days  total cases  mean cases
# saturday          25         1603        64.1
# sunday            24         1177        49.0
# monday            24         1188        49.5
# tuesday           24         1382        57.6
# wednesday         24         1367        57.0
# thursday          24         1382        57.6
# friday            24         1504        62.7

# %%
plt.bar(x = list(dayofweek_df.index), height = list(dayofweek_df["day of week average"].values))
plt.show()

# %%
df.loc[df.Date.map(lambda x: "Apr" in x)]
# Out:
#       Date  new.cases        day
# 67   1-Apr        306  wednesday
# 68   2-Apr        277   thursday
# 69   3-Apr        226     friday
# 70   4-Apr        190   saturday
# 71   5-Apr        143     sunday
# 72   6-Apr        107     monday
# 73   7-Apr        119    tuesday
# 74   8-Apr        105  wednesday
# 75   9-Apr         85   thursday
# 76  10-Apr        107     friday
# 77  11-Apr         97   saturday
# 78  12-Apr         36     sunday
# 79  13-Apr         44     monday
# 80  14-Apr         49    tuesday
# 81  15-Apr         38  wednesday
# 82  16-Apr         33   thursday
# 83  17-Apr         47     friday
# 84  18-Apr         43   saturday
# 85  19-Apr         45     sunday
# 86  20-Apr         11     monday
# 87  21-Apr         23    tuesday
# 88  22-Apr         12  wednesday
# 89  23-Apr          8   thursday
# 90  24-Apr         20     friday
# 91  25-Apr         20   saturday
# 92  26-Apr         18     sunday
# 93  27-Apr          8     monday
# 94  28-Apr         12    tuesday
# 95  29-Apr         17  wednesday
# 96  30-Apr         11   thursday
